# %%
#importing the basic python libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings

# %%
#loading the data
data = pd.read_csv('C:/Users/Pradeep Kumar Yadav/Downloads/Data science Assignment/Data science Assignment/DS_dataset (1) (4) (3).csv')

# %%
data.head()
# Out:
#    userID  Contact_ind  Customer_status  ActiveSinceDays  num_AcD_m0  \
# 0   13845            1                3              487           1
# 1   38029            1                0             1002           2
# 2   43994            1                3              256           5
# 3    7735            1                3             1190           7
# 4   25444            1                3              781           2
#
#    num_AcD_m1  r_AcD_m0_m12  r_AcD_m0_m123  daystofirstload  \
# 0           1     66.666667      50.000000                0
# 1           5     66.666667      85.714286                0
# 2           4     76.923077      62.500000                0
# 3           9     93.333333      61.764706                0
# 4           2     57.142857      35.294118                0
#
#    dayssincelastload  ...  InAllRev_m1  InAllRev_m2  r_InAllRev_m0_m1  \
# 0                 16  ...       1000.0          0.0          0.000000
# 1                194  ...          0.0          0.0          0.000000
# 2                 29  ...          0.0       2548.0          0.000000
# 3                  3  ...       7636.0       4500.0        137.488543
# 4                 59  ...       2000.0       1500.0         74.962519
#
#    r_InAllRev_m0_m2  tot_InAllRev_3m  OgAllRev_m0  OgAllRev_m1  OgAllRev_m2  \
# 0          0.000000           1000.0       177.00        300.0        399.0
# 1          0.000000              0.0      5700.00      13917.0          0.0
# 2          0.000000           2548.0      1068.00        299.0       3058.0
# 3        233.281493          22636.0     10389.00       8758.0       5377.0
# 4         99.933378           5000.0      1637.87       2759.0       2830.8
#
#    tot_OgAllRev_3m  targetid
# 0           876.00         0
# 1         19617.00         1
# 2          4425.00         0
# 3         24524.00         0
# 4          7227.67         0
#
# [5 rows x 110 columns]

# %%
data.tail()
# Out:
#        userID  Contact_ind  Customer_status  ActiveSinceDays  num_AcD_m0  \
# 44995    5927            1                3              137           1
# 44996   41004            1                3              510           4
# 44997   23839            1                3             1111           8
# 44998     324            1                3             1162           2
# 44999    1985            0                3              128           4
#
#        num_AcD_m1  r_AcD_m0_m12  r_AcD_m0_m123  daystofirstload  \
# 44995           3     25.000000      30.000000              107
# 44996           6     72.727273      70.588235                8
# 44997           5    145.454545     200.000000              949
# 44998           0     44.444444      66.666667                0
# 44999           1    266.666667     400.000000                0
#
#        dayssincelastload  ...  InAllRev_m1  InAllRev_m2  r_InAllRev_m0_m1  \
# 44995                 54  ...          0.0          0.0          0.000000
# 44996                144  ...          0.0       1295.0          0.000000
# 44997                 20  ...        210.0       5180.0        372.037915
# 44998                 23  ...          0.0       1000.0      54100.000000
# 44999                152  ...          0.0        458.0          0.000000
#
#        r_InAllRev_m0_m2  tot_InAllRev_3m  OgAllRev_m0  OgAllRev_m1  \
# 44995          0.000000              0.0        100.0        320.0
# 44996          0.000000           1295.0       3365.0       3123.0
# 44997         15.151515           6175.0       1570.0       4896.0
# 44998         54.045954           1541.0        548.0          0.0
# 44999          0.000000            458.0         30.0          0.0
#
#        OgAllRev_m2  tot_OgAllRev_3m  targetid
# 44995       1478.0           1898.0         0
# 44996       1838.0           8326.0         0
# 44997        952.0           7418.0         0
# 44998       1099.3           1647.3         0
# 44999        458.0            488.0         0
#
# [5 rows x 110 columns]

# %%
data.describe()
# Out:
#              userID   Contact_ind  Customer_status  ActiveSinceDays  \
# count  45000.000000  45000.000000     45000.000000     45000.000000
# mean   25041.195822      0.889711         2.814467       713.220489
# std    14431.467847      0.313253        15.689957       529.159190
# min        1.000000      0.000000      -999.000000      -999.000000
# 25%    12584.750000      1.000000         3.000000       260.000000
# 50%    25032.500000      1.000000         3.000000       550.000000
# 75%    37544.250000      1.000000         4.000000      1081.000000
# max    50000.000000      1.000000         4.000000      2999.000000
#
#          num_AcD_m0    num_AcD_m1  r_AcD_m0_m12  r_AcD_m0_m123  \
# count  45000.000000  45000.000000  45000.000000   45000.000000
# mean       4.385089      4.603356    112.648446     118.468647
# std        3.856362      4.183600    104.957227     102.317085
# min        1.000000      0.000000      4.444444       4.285714
# 25%        2.000000      2.000000     55.555556      60.000000
# 50%        3.000000      3.000000     88.888889      95.454545
# 75%        6.000000      6.000000    133.333333     150.000000
# max       30.000000     31.000000   3600.000000    2550.000000
#
#        daystofirstload  dayssincelastload  ...    InAllRev_m1    InAllRev_m2  \
# count     45000.000000       45000.000000  ...   45000.000000   45000.000000
# mean        135.516911          30.327956  ...    2718.702036    2390.171991
# std         400.185235         184.400482  ...   10186.519593    7148.565788
# min        -999.000000        -999.000000  ...       0.000000       0.000000
# 25%           0.000000           9.000000  ...       0.000000       0.000000
# 50%           3.000000          39.000000  ...     300.000000     408.000000
# 75%         156.000000          94.000000  ...    1600.205000    1741.087500
# max        2569.000000         246.000000  ...  718900.000000  556440.000000
#
#        r_InAllRev_m0_m1  r_InAllRev_m0_m2  tot_InAllRev_3m   OgAllRev_m0  \
# count      4.500000e+04      4.500000e+04     4.500000e+04  4.500000e+04
# mean       4.901471e+04      6.545325e+04     7.909437e+03  3.396933e+03
# std        4.442160e+05      6.112116e+05     2.413073e+04  1.275428e+04
# min        0.000000e+00      0.000000e+00     0.000000e+00  5.000000e-01
# 25%        0.000000e+00      0.000000e+00     4.990000e+02  2.790000e+02
# 50%        3.331113e+01      3.223729e+01     1.731000e+03  7.467750e+02
# 75%        2.044804e+02      2.288739e+02     6.337390e+03  2.400000e+03
# max        2.210620e+07      6.506785e+07     2.342540e+06  1.152048e+06
#
#          OgAllRev_m1    OgAllRev_m2  tot_OgAllRev_3m      targetid
# count   45000.000000   45000.000000     4.500000e+04  45000.000000
# mean     3182.273750    2811.989288     9.391196e+03      0.203044
# std     10710.336636    8130.998706     2.732669e+04      0.402270
# min         0.000000       0.000000     1.000000e+00      0.000000
# 25%       199.000000     100.000000     1.165875e+03      0.000000
# 50%       733.000000     626.100000     2.800450e+03      0.000000
# 75%      2387.000000    2305.250000     8.628410e+03      0.000000
# max    760763.250000  703016.000000     2.577306e+06      1.000000
#
# [8 rows x 110 columns]

# %%
#check the shape of the dataset
data.shape
# Out:
# (45000, 110)

# %%
# check columns of dataset
for line in data:
  print(line)
# Out:
# userID
# Contact_ind
# Customer_status
# ActiveSinceDays
# num_AcD_m0
# num_AcD_m1
# r_AcD_m0_m12
# r_AcD_m0_m123
# daystofirstload
# dayssincelastload
# tot_RevUo_m0
# tot_RevUo_m1
# tot_RevUo_m2
# r_tot_RevUo_m0_m1
# r_tot_RevUo_m1_m2
# r_tot_RevUo_m0_m12
# avg_RevUo_m0
# avg_RevUo_m1
# avg_RevUo_m2
# chg_RevUo_l0_1m
# chg_RevUo_l1_2m
# chg_RevUo_l2_3m
# tot_LdCnt_m0
# tot_LdCnt_m1
# tot_LdCnt_m2
# max_RevUo_m0
# max_RevUo_m1
# max_RevUo_m2
# r_avg_RevUo_m0_m1
# r_avg_RevUo_m1_m2
# avgdays_btw_loads_l6
# tot_failed_LdTxnCnt_3m
# r_failed_LdTxnCnt_m0_m12
# tot_rtlX_m0
# tot_rtlX_m1
# tot_rtlX_m2
# r_tot_rtlX_m0_m1
# r_tot_rtlX_m1_m2
# r_tot_rtlX_m0_m12
# avg_rtlX_m0
# avg_rtlX_m1
# avg_rtlX_m2
# max_rtlX_m0
# max_rtlX_m1
# max_rtlX_m2
# r_avg_max_rtlX_m0
# r_avg_max_rtlX_m1
# RtlTxns_cnt_m0
# RtlTxns_cnt_m1
# RtlTxns_cnt_m2
# r_RtlTxns_cnt_m0_m1
# r_RtlTxns_cnt_m1_m2
# sum_r_RtlTxns_cnt
# fail_RtlTxncnt_m0
# RtlTxn_dayscnt_m0
# RtlTxn_dayscnt_m1
# RtlTxn_dayscnt_m2
# tot_rechX_m0
# tot_rechX_m1
# tot_rechX_m2
# chg_rechX_l0_1m
# chg_rechX_l1_2m
# avg_rechX_m0
# avg_rechX_m1
# avg_rechX_m2
# max_rechX_m0
# max_rechX_m1
# max_rechX_m2
# r_avg_max_rechX_m0
# r_avg_max_rechX_m1
# rechtxns_cnt_m0
# rechtxns_cnt_m1
# rechtxns_cnt_m2
# rechtxn_dayscnt_m0
# rechtxn_dayscnt_m1
# rechtxn_dayscnt_m2
# billX_amt_m0
# billX_amt_m1
# billX_amt_m2
# tot_billX_amt_m012
# r_billX_amt_m0_m1
# r_billX_amt_m0_m12
# r_billX_amt_m1_m2
# billX_cnt_m0
# billX_cnt_m1
# billX_cnt_m2
# rech_amt_m0
# rech_amt_m1
# rech_amt_m2
# r_rech_amt_m0_m1
# r_rech_amt_m1_m2
# sum_r_rech_amt_m1m2_m0m1
# r_rech_amt_m0_m12
# avgbal_m0
# avgbal_m1
# avgbal_m2
# resolved_cnt_m2
# tot_resolved_cnt_m012
# percent_resolved_3m
# InAllRev_m0
# InAllRev_m1
# InAllRev_m2
# r_InAllRev_m0_m1
# r_InAllRev_m0_m2
# tot_InAllRev_3m
# OgAllRev_m0
# OgAllRev_m1
# OgAllRev_m2
# tot_OgAllRev_3m
# targetid

# %%
#checking the data type
data.dtypes
# Out:
# userID               int64
# Contact_ind          int64
# Customer_status      int64
# ActiveSinceDays      int64
# num_AcD_m0           int64
#                     ...
# OgAllRev_m0        float64
# OgAllRev_m1        float64
# OgAllRev_m2        float64
# tot_OgAllRev_3m    float64
# targetid             int64
# Length: 110, dtype: object

# %%
data.info
# Out:
# <bound method DataFrame.info of        userID  Contact_ind  Customer_status  ActiveSinceDays  num_AcD_m0  \
# 0       13845            1                3              487           1
# 1       38029            1                0             1002           2
# 2       43994            1                3              256           5
# 3        7735            1                3             1190           7
# 4       25444            1                3              781           2
# ...       ...          ...              ...              ...         ...
# 44995    5927            1                3              137           1
# 44996   41004            1                3              510           4
# 44997   23839            1                3             1111           8
# 44998     324            1                3             1162           2
# 44999    1985            0                3              128           4
#
#        num_AcD_m1  r_AcD_m0_m12  r_AcD_m0_m123  daystofirstload  \
# 0               1     66.666667      50.000000                0
# 1               5     66.666667      85.714286                0
# 2               4     76.923077      62.500000                0
# 3               9     93.333333      61.764706                0
# 4               2     57.142857      35.294118                0
# ...           ...           ...            ...              ...
# 44995           3     25.000000      30.000000              107
# 44996           6     72.727273      70.588235                8
# 44997           5    145.454545     200.000000              949
# 44998           0     44.444444      66.666667                0
# 44999           1    266.666667     400.000000                0
#
#        dayssincelastload  ...  InAllRev_m1  InAllRev_m2  r_InAllRev_m0_m1  \
# 0                     16  ...       1000.0          0.0          0.000000
# 1                    194  ...          0.0          0.0          0.000000
# 2                     29  ...          0.0       2548.0          0.000000
# 3                      3  ...       7636.0       4500.0        137.488543
# 4                     59  ...       2000.0       1500.0         74.962519
# ...                  ...  ...          ...          ...               ...
# 44995                 54  ...          0.0          0.0          0.000000
# 44996                144  ...          0.0       1295.0          0.000000
# 44997                 20  ...        210.0       5180.0        372.037915
# 44998                 23  ...          0.0       1000.0      54100.000000
# 44999                152  ...          0.0        458.0          0.000000
#
#        r_InAllRev_m0_m2  tot_InAllRev_3m  OgAllRev_m0  OgAllRev_m1  \
# 0              0.000000           1000.0       177.00        300.0
# 1              0.000000              0.0      5700.00      13917.0
# 2              0.000000           2548.0      1068.00        299.0
# 3            233.281493          22636.0     10389.00       8758.0
# 4             99.933378           5000.0      1637.87       2759.0
# ...                 ...              ...          ...          ...
# 44995          0.000000              0.0       100.00        320.0
# 44996          0.000000           1295.0      3365.00       3123.0
# 44997         15.151515           6175.0      1570.00       4896.0
# 44998         54.045954           1541.0       548.00          0.0
# 44999          0.000000            458.0        30.00          0.0
#
#        OgAllRev_m2  tot_OgAllRev_3m  targetid
# 0            399.0           876.00         0
# 1              0.0         19617.00         1
# 2           3058.0          4425.00         0
# 3           5377.0         24524.00         0
# 4           2830.8          7227.67         0
# ...            ...              ...       ...
# 44995       1478.0          1898.00         0
# 44996       1838.0          8326.00         0
# 44997        952.0          7418.00         0
# 44998       1099.3          1647.30         0
# 44999        458.0           488.00         0
#
# [45000 rows x 110 columns]>

# %%
# Check for missing values in all the columnns of the dataset
data.isnull().sum()
# Out:
# userID             0
# Contact_ind        0
# Customer_status    0
# ActiveSinceDays    0
# num_AcD_m0         0
#                   ..
# OgAllRev_m0        0
# OgAllRev_m1        0
# OgAllRev_m2        0
# tot_OgAllRev_3m    0
# targetid           0
# Length: 110, dtype: int64

# %%
#getting the correlation values of all the coulms
data.corr()
# Out:
#                    userID  Contact_ind  Customer_status  ActiveSinceDays  \
# userID           1.000000     0.005175        -0.001200         0.002675
# Contact_ind      0.005175     1.000000        -0.004973         0.301282
# Customer_status -0.001200    -0.004973         1.000000         0.048628
# ActiveSinceDays  0.002675     0.301282         0.048628         1.000000
# num_AcD_m0       0.002577     0.043473        -0.004865         0.031596
# ...                   ...          ...              ...              ...
# OgAllRev_m0      0.001223     0.014296        -0.007652         0.006819
# OgAllRev_m1      0.000779     0.006343        -0.002411        -0.001987
# OgAllRev_m2      0.007801     0.000238        -0.005062         0.010019
# tot_OgAllRev_3m  0.003198     0.009230        -0.006023         0.005385
# targetid         0.003422    -0.030560        -0.002619        -0.063343
#
#                  num_AcD_m0  num_AcD_m1  r_AcD_m0_m12  r_AcD_m0_m123  \
# userID             0.002577    0.001976     -0.003853      -0.000569
# Contact_ind        0.043473    0.038890      0.002101      -0.005541
# Customer_status   -0.004865    0.000848      0.000798       0.002249
# ActiveSinceDays    0.031596    0.023526     -0.020887      -0.061304
# num_AcD_m0         1.000000    0.654226      0.285915       0.328624
# ...                     ...         ...           ...            ...
# OgAllRev_m0        0.287352    0.179502      0.105978       0.132983
# OgAllRev_m1        0.224435    0.316635     -0.035307       0.001389
# OgAllRev_m2        0.202709    0.221741     -0.089014      -0.075981
# tot_OgAllRev_3m    0.282397    0.273859      0.009140       0.040004
# targetid          -0.237220   -0.194992     -0.023600      -0.041279
#
#                  daystofirstload  dayssincelastload  ...  InAllRev_m1  \
# userID                  0.001666           0.002029  ...     0.003008
# Contact_ind             0.174993           0.074617  ...     0.007399
# Customer_status         0.046017          -0.000273  ...    -0.001512
# ActiveSinceDays         0.605564           0.048979  ...    -0.006306
# num_AcD_m0              0.022542          -0.022510  ...     0.218943
# ...                          ...                ...  ...          ...
# OgAllRev_m0             0.018428          -0.030037  ...     0.557330
# OgAllRev_m1             0.015585          -0.027997  ...     0.841758
# OgAllRev_m2             0.014271          -0.037667  ...     0.413754
# tot_OgAllRev_3m         0.018955          -0.036200  ...     0.713152
# targetid               -0.021065           0.060382  ...    -0.067169
#
#                  InAllRev_m2  r_InAllRev_m0_m1  r_InAllRev_m0_m2  \
# userID              0.004583         -0.004207         -0.003424
# Contact_ind         0.009117          0.005308          0.000411
# Customer_status    -0.004239          0.000562         -0.000194
# ActiveSinceDays     0.005939          0.000084         -0.001314
# num_AcD_m0          0.202100          0.029883          0.061040
# ...                      ...               ...               ...
# OgAllRev_m0         0.428784          0.219009          0.382019
# OgAllRev_m1         0.489753         -0.012733          0.085212
# OgAllRev_m2         0.844325          0.048777         -0.029715
# tot_OgAllRev_3m     0.643307          0.111742          0.202857
# targetid           -0.072564         -0.015622         -0.015505
#
#                  tot_InAllRev_3m  OgAllRev_m0  OgAllRev_m1  OgAllRev_m2  \
# userID                  0.001741     0.001223     0.000779     0.007801
# Contact_ind             0.013615     0.014296     0.006343     0.000238
# Customer_status        -0.005390    -0.007652    -0.002411    -0.005062
# ActiveSinceDays         0.002945     0.006819    -0.001987     0.010019
# num_AcD_m0              0.275742     0.287352     0.224435     0.202709
# ...                          ...          ...          ...          ...
# OgAllRev_m0             0.782422     1.000000     0.683731     0.560111
# OgAllRev_m1             0.768112     0.683731     1.000000     0.575758
# OgAllRev_m2             0.621188     0.560111     0.575758     1.000000
# tot_OgAllRev_3m         0.851067     0.901372     0.882372     0.784631
# targetid               -0.084691    -0.067043    -0.064287    -0.066002
#
#                  tot_OgAllRev_3m  targetid
# userID                  0.003198  0.003422
# Contact_ind             0.009230 -0.030560
# Customer_status        -0.006023 -0.002619
# ActiveSinceDays         0.005385 -0.063343
# num_AcD_m0              0.282397 -0.237220
# ...                          ...       ...
# OgAllRev_m0             0.901372 -0.067043
# OgAllRev_m1             0.882372 -0.064287
# OgAllRev_m2             0.784631 -0.066002
# tot_OgAllRev_3m         1.000000 -0.076126
# targetid               -0.076126  1.000000
#
# [110 rows x 110 columns]

# %%
#heatmap
#df=data.corr()
 #Using seaborn
#pd.corr(data_load)
# %matplotlib inline
# top_corr_features = df.index
# plt.figure(figsize=(100,100))
# #plot heat map
# #sns.heatmap(df,annot=True, cmap='coolwarm')
# g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
#split the data in dependent and independent features
X=data.iloc[:,0:-1]
y=data.iloc[:,-1]
y
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 44995    0
# 44996    0
# 44997    0
# 44998    0
# 44999    0
# Name: targetid, Length: 45000, dtype: int64

# %%
#counting the target varibles category
y.value_counts()
# Out:
# 0    35863
# 1     9137
# Name: targetid, dtype: int64

# %%
# count plot of flag column
#as target variable is imbalence so we need to balence the data to make the acccurate model
ax=sns.countplot(y)
# Out:
# C:\Users\Pradeep Kumar Yadav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#calculating the correlation of the independent coulums
data.corr()
# Out:
#                    userID  Contact_ind  Customer_status  ActiveSinceDays  \
# userID           1.000000     0.005175        -0.001200         0.002675
# Contact_ind      0.005175     1.000000        -0.004973         0.301282
# Customer_status -0.001200    -0.004973         1.000000         0.048628
# ActiveSinceDays  0.002675     0.301282         0.048628         1.000000
# num_AcD_m0       0.002577     0.043473        -0.004865         0.031596
# ...                   ...          ...              ...              ...
# OgAllRev_m0      0.001223     0.014296        -0.007652         0.006819
# OgAllRev_m1      0.000779     0.006343        -0.002411        -0.001987
# OgAllRev_m2      0.007801     0.000238        -0.005062         0.010019
# tot_OgAllRev_3m  0.003198     0.009230        -0.006023         0.005385
# targetid         0.003422    -0.030560        -0.002619        -0.063343
#
#                  num_AcD_m0  num_AcD_m1  r_AcD_m0_m12  r_AcD_m0_m123  \
# userID             0.002577    0.001976     -0.003853      -0.000569
# Contact_ind        0.043473    0.038890      0.002101      -0.005541
# Customer_status   -0.004865    0.000848      0.000798       0.002249
# ActiveSinceDays    0.031596    0.023526     -0.020887      -0.061304
# num_AcD_m0         1.000000    0.654226      0.285915       0.328624
# ...                     ...         ...           ...            ...
# OgAllRev_m0        0.287352    0.179502      0.105978       0.132983
# OgAllRev_m1        0.224435    0.316635     -0.035307       0.001389
# OgAllRev_m2        0.202709    0.221741     -0.089014      -0.075981
# tot_OgAllRev_3m    0.282397    0.273859      0.009140       0.040004
# targetid          -0.237220   -0.194992     -0.023600      -0.041279
#
#                  daystofirstload  dayssincelastload  ...  InAllRev_m1  \
# userID                  0.001666           0.002029  ...     0.003008
# Contact_ind             0.174993           0.074617  ...     0.007399
# Customer_status         0.046017          -0.000273  ...    -0.001512
# ActiveSinceDays         0.605564           0.048979  ...    -0.006306
# num_AcD_m0              0.022542          -0.022510  ...     0.218943
# ...                          ...                ...  ...          ...
# OgAllRev_m0             0.018428          -0.030037  ...     0.557330
# OgAllRev_m1             0.015585          -0.027997  ...     0.841758
# OgAllRev_m2             0.014271          -0.037667  ...     0.413754
# tot_OgAllRev_3m         0.018955          -0.036200  ...     0.713152
# targetid               -0.021065           0.060382  ...    -0.067169
#
#                  InAllRev_m2  r_InAllRev_m0_m1  r_InAllRev_m0_m2  \
# userID              0.004583         -0.004207         -0.003424
# Contact_ind         0.009117          0.005308          0.000411
# Customer_status    -0.004239          0.000562         -0.000194
# ActiveSinceDays     0.005939          0.000084         -0.001314
# num_AcD_m0          0.202100          0.029883          0.061040
# ...                      ...               ...               ...
# OgAllRev_m0         0.428784          0.219009          0.382019
# OgAllRev_m1         0.489753         -0.012733          0.085212
# OgAllRev_m2         0.844325          0.048777         -0.029715
# tot_OgAllRev_3m     0.643307          0.111742          0.202857
# targetid           -0.072564         -0.015622         -0.015505
#
#                  tot_InAllRev_3m  OgAllRev_m0  OgAllRev_m1  OgAllRev_m2  \
# userID                  0.001741     0.001223     0.000779     0.007801
# Contact_ind             0.013615     0.014296     0.006343     0.000238
# Customer_status        -0.005390    -0.007652    -0.002411    -0.005062
# ActiveSinceDays         0.002945     0.006819    -0.001987     0.010019
# num_AcD_m0              0.275742     0.287352     0.224435     0.202709
# ...                          ...          ...          ...          ...
# OgAllRev_m0             0.782422     1.000000     0.683731     0.560111
# OgAllRev_m1             0.768112     0.683731     1.000000     0.575758
# OgAllRev_m2             0.621188     0.560111     0.575758     1.000000
# tot_OgAllRev_3m         0.851067     0.901372     0.882372     0.784631
# targetid               -0.084691    -0.067043    -0.064287    -0.066002
#
#                  tot_OgAllRev_3m  targetid
# userID                  0.003198  0.003422
# Contact_ind             0.009230 -0.030560
# Customer_status        -0.006023 -0.002619
# ActiveSinceDays         0.005385 -0.063343
# num_AcD_m0              0.282397 -0.237220
# ...                          ...       ...
# OgAllRev_m0             0.901372 -0.067043
# OgAllRev_m1             0.882372 -0.064287
# OgAllRev_m2             0.784631 -0.066002
# tot_OgAllRev_3m         1.000000 -0.076126
# targetid               -0.076126  1.000000
#
# [110 rows x 110 columns]

# %%
# import pipeline
from sklearn.pipeline import Pipeline
#import standaer scalar
from sklearn.preprocessing import StandardScaler
# import simple imputer
from sklearn.impute import SimpleImputer

# %%
#missing_values type for imputation
imputer = SimpleImputer(missing_values = np.nan,
                        strategy ='mean')

# Fitting the data to the imputer object
imputer = imputer.fit(X)
 
# Imputing the data   
X = imputer.transform(X)
 
# print("Imputed Data : \n", X)
# # 2. standard scalar 
# object= StandardScaler() 
# # standardization 
# scale = object.fit_transform(X) 
# print(scale)

# %%
#getting the shape of the independent varibles
X.shape
# Out:
# (45000, 109)

# %%
# import train test split
from sklearn.model_selection import train_test_split

# %%
# Split into training (80%) and testing set (20%)
train_x, test_x, train_y, test_y= train_test_split(X,y,test_size=0.2,random_state=41)

# check the shape of train and test
train_x.shape,train_y.shape,test_x.shape, test_y.shape
# Out:
# ((36000, 109), (36000,), (9000, 109), (9000,))

# %%
#from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
#ros = RandomOverSampler(sampling_strategy='not minority') # Float
ros = RandomUnderSampler(sampling_strategy=1) # String
X_train_res, y_train_res = ros.fit_resample(train_x, train_y)

# %%
# importing necessary libraries for geting metrics of models
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score,roc_auc_score,roc_curve

# %%
# rf=RandomForestClassifier(n_estimators=300, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=1,min_weight_fraction_leaf=0.0,
#                                       max_features='sqrt', max_leaf_nodes=None,
#                                       bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False,
#                                       class_weight=None, ccp_alpha=0.0, max_samples=None)

# %%
# ##implement the XGBoost classifier

from xgboost import XGBClassifier


# declare parameters
params = {
            
            'max_depth': 5,
            'alpha': 10,
            'learning_rate': 0.1,
            'n_estimators':250
        }
            
            
            
# instantiate the classifier 
xgb_clf = XGBClassifier(**params)



# fit the classifier to the training data
xgb_clf.fit(X_train_res, y_train_res)
# Out:
# XGBClassifier(alpha=10, base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=5, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=250, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', ...)

# %%
#rf.fit(X_train_res,y_train_res)

# Predicting the test set results
y_pred = xgb_clf.predict(test_x)
#y_pred = rf.predict(test_x)
ACC=(accuracy_score(test_y, y_pred))
print(ACC)
print(classification_report(test_y,y_pred))
# Out:
# 0.8227777777777778
#               precision    recall  f1-score   support
#
#            0       0.98      0.80      0.88      7200
#            1       0.53      0.92      0.68      1800
#
#     accuracy                           0.82      9000
#    macro avg       0.75      0.86      0.78      9000
# weighted avg       0.89      0.82      0.84      9000

# %%
#plotting the ROC and AUC
roc_auc = roc_auc_score(test_y, y_pred)

false_positive_rate, true_positive_rate, thresolds =roc_curve(test_y, y_pred)

plt.figure(figsize=(10, 8), dpi=80)
plt.axis('scaled')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.title("AUC & ROC Curve")
plt.plot(false_positive_rate, true_positive_rate, 'g')
plt.fill_between(false_positive_rate, true_positive_rate, facecolor='lightgreen', alpha=0.7)
plt.text(0.95, 0.05, 'AUC = %0.4f' % roc_auc, ha='right', fontsize=10, weight='bold', color='blue')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.show()

# %%
'''
From the classification report we can obseve that model performed well on '0' target variable but performed poor on '1' calss.
so it means we have to look on minority class in depth to improve the model accuracy.
'''
# Out:
# "\nFrom the classification report we can obseve that model performed well on '0' target variable but performed poor on '1' calss.\nso it means we have to look on minority class in depth to improve the model accuracy.\n"

# %%
'''Evaluating the churn of the validation data
'''
valid_data = pd.read_csv('C:/Users/Pradeep Kumar Yadav/Downloads/Data science Assignment/Data science Assignment/validation.csv')
valid_data.iloc[:,0]
# Out:
# 0       42193
# 1       38122
# 2       38248
# 3       41562
# 4       28472
#         ...
# 4995    43714
# 4996    19322
# 4997    12108
# 4998    27784
# 4999    35911
# Name: userID, Length: 5000, dtype: int64

# %%
#missing_values type for imputation
imputer = SimpleImputer(missing_values = np.nan,
                        strategy ='mean')

# Fitting the data to the imputer object
imputer = imputer.fit(valid_data)
 
# Imputing the data    
valid_data_df = imputer.transform(valid_data)
valid_data_df.shape
#len(valid_data)
# Out:
# (5000, 109)

# %%
valid_pred = xgb_clf.predict(valid_data_df)
print("validation report:",valid_pred)
# for i in valid_pred:
#     print(i)
# Out:
# validation report: [0 0 0 ... 0 0 0]

# %%
#creating the final validtion report and stored in csv file
validation_pred=pd.DataFrame(valid_pred,columns=['targetid'], index=None)
valid_df = pd.merge(valid_data['userID'],validation_pred,  left_index=True, right_index=True)
#valid_df.to_csv('C:/Users/Pradeep Kumar Yadav/Downloads/Data science Assignment/Data science Assignment/churn_Validation_report.csv')
